# %% [markdown]
# # Install Libraries

# %%
# !pip install -r requirements.txt

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd

# %% [markdown]
# # Read csv

# %%
df = pd.read_csv("data.csv")

# %% [markdown]
# # Samples

# %%
df.head()
# Out:
#    clnt_id  bank_id  acc_id  txn_id         txn_date  \
# 0        6        1       1      54  31/07/2023 0:00
# 1        6        1       1      27  31/07/2023 0:00
# 2        6        1       1      11  01/08/2023 0:00
# 3       28        1       1     108  25/07/2023 0:00
# 4       28        1       1     136  14/08/2023 0:00
#
#                                                 desc     amt    cat   merchant
# 0                                       CLOC Advance   6.286  Shops        NaN
# 1                                       CLOC Advance   6.286  Shops        NaN
# 2                                       CLOC Advance   2.268  Shops        NaN
# 3  1INFINITELOOP@ 07/25 #68 PMNT RCVD 1INFINITELO...  59.100  Shops  1INFINITE
# 4  1INFINITELOOP@ 08/14 #68 PMNT RCVD 1INFINITELO...   4.924  Shops  1INFINITE

# %% [markdown]
# # Get Numerical Data Stat

# %%
df.describe()
# Out:
#              clnt_id        bank_id         acc_id         txn_id  \
# count  257063.000000  257063.000000  257063.000000  257063.000000
# mean      748.830886     345.330040     394.900028   70422.018046
# std       251.988665     317.588198     364.916636   63111.353552
# min         1.000000       1.000000       1.000000       1.000000
# 25%       821.000000       2.000000       2.000000     227.000000
# 50%       880.000000     296.000000     332.000000   61624.000000
# 75%       880.000000     609.000000     702.000000  126078.500000
# max       880.000000     990.000000    1131.000000  190505.000000
#
#                  amt
# count  257063.000000
# mean        2.321870
# std        80.871399
# min     -9162.460000
# 25%        -6.000000
# 50%        -1.908000
# 75%         1.950000
# max      9397.830000

# %% [markdown]
# amt tends to have more savings.

# %% [markdown]
# # Find correlation on the data

# %%
df[["clnt_id", "bank_id", "acc_id", "txn_id", "amt"]].corr()
# Out:
#           clnt_id   bank_id    acc_id    txn_id       amt
# clnt_id  1.000000  0.564058  0.561435  0.580178 -0.279752
# bank_id  0.564058  1.000000  0.999585  0.424093 -0.199057
# acc_id   0.561435  0.999585  1.000000  0.422072 -0.197959
# txn_id   0.580178  0.424093  0.422072  1.000000 -0.211134
# amt     -0.279752 -0.199057 -0.197959 -0.211134  1.000000

# %% [markdown]
# The highest correlation is bank id and account id.

# %% [markdown]
# # Get all unique values of each categorical columns

# %% [markdown]
# ## Description column

# %%
list(df["desc"].unique())
# Out:
# ['CLOC Advance',
#  '1INFINITELOOP@ 07/25 #68 PMNT RCVD 1INFINITELOOP@APP 68 CA',
#  '1INFINITELOOP@ 08/14 #68 PMNT RCVD 1INFINITELOOP@APP 68 CA',
#  '1INFINITELOOP@ 08/20 #68 PMNT RCVD 1INFINITELOOP@APP 68 CA',
#  '1INFINITELOOP@ 08/19 #68 PMNT RCVD 1INFINITELOOP@APP 68 CA',
#  '1INFINITELOOP@ 08/13 #68 PMNT RCVD 1INFINITELOOP@APP 68 CA',
#  '1INFINITELOOP@ 08/21 #68 PMNT RCVD 1INFINITELOOP@APP 68 CA',
#  '1INFINITELOOP@ 08/03 #68 PMNT RCVD 1INFINITELOOP@APP 68 CA',
#  '1INFINITELOOP@ 08/26 #68 PMNT RCVD 1INFINITELOOP@APP 68 CA',
#  'Zelle Transfer Conf# 0HVBASS4U; Summer June',
#  'Zelle Transfer Conf# 0HVIE2WMH; Summer June',
#  'AMAZON.COM, INC.',
#  'APPLE CASH INST XFER',
#  '09-03-23 77 CA 2990 APPLE CASH INST XFER VISA MONEY TRANSFER CREDIT',
#  '07-18-23 VISA DIRECT CA 2990 APPLE CASH INST XFER VISA MONEY TRANSFER CREDIT',
#  '06-24-23 VISA DIRECT CA 2990 APPLE CASH INST XFER VISA MONEY TRANSFER CREDIT',
# ...

# %% [markdown]
# ## Category column

# %%
list(df["cat"].unique())
# Out:
# ['Shops',
#  'Telecommunication Services',
#  'Utilities',
#  'Insurance',
#  'Clothing and Accessories',
#  'Digital Entertainment',
#  'Gyms and Fitness Centers',
#  'Department Stores',
#  'Healthcare',
#  'Service',
#  'Travel',
#  'Arts and Entertainment',
#  'Interest',
#  'Tax Refund',
#  'Bank Fee',
#  'Payment',
#  'Restaurants',
#  'Supermarkets and Groceries',
#  'Gas Stations',
#  'Convenience Stores',
#  'Loans',
#  'Transfer Credit',
#  'Transfer Deposit',
#  'Payroll',
#  'Uncategorized',
#  'Check Deposit',
#  'Third Party',
#  'Internal Account Transfer',
#  'Bank Fees',
#  'Transfer',
#  'Transfer Debit',
#  'ATM']

# %% [markdown]
# ## Merchant column

# %%
list(df["merchant"].unique())
# Out:
# [nan,
#  '1INFINITE',
#  'Zelle',
#  'Amazon',
#  'Apple',
#  'AutoZone',
#  'Best Buy',
#  'AdvanceAutoPar',
#  'Takeda Pharm',
#  "Dick's Sporting",
#  'Microsoft',
#  'Credit Genie',
#  'YouFlowers',
#  ' Amazon.com, inc',
#  "O'Reilly Auto",
#  'Apple Cash',
#  'HVAC TRAN',
#  'NAPA AUTO',
#  'Apple Cash Bank',
#  'PlayStation Network',
#  'Tiny Heart Heroes',
#  'Advance Auto Parts',
#  'FINWISE',
#  'ADOBE',
#  'Microsoft Store',
#  'Steam Games',
#  'NAVchek Adv',
#  'FAMILY DOLLAR',
#  'DOLLAR TREE',
#  'DOLLAR GENERAL',
#  'Hallmark Petrol',
#  'Apple Cash Balance',
#  'Dollar General',
#  'Dollartre',
#  'Dollartree',
#  'Cag Acceptance L',
#  'Virtual Racing Sch',
#  'Lowes Fuel',
#  'GameStop',
#  'Bespoke Post',
#  'UOWN LEAS',
#  'Santander',
#  'Blizzard Entertainment',
#  'CASH APP',
#  'Oculus',
#  'PlaystationNetwork',
#  'PayPal',
#  'Toyota',
#  'Blizzard',
#  'Empower',
#  'AAFES/TR',
#  'Chevrolet',
#  'Roblox',
#  'Adobe',
#  'FIVE BELOW',
# ...
